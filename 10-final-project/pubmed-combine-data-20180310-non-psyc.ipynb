# %%
# this file combines the separate csv files of filtered data into one large csv file
# require: ./intermediate_data_nonpsyc/*.csv

# %%
import glob
import pandas as pd
import ast

# %%
filenames = glob.glob("./intermediate_data_nonpsyc/*.pkl")
print(filenames) # len 4
# Out:
# ['./intermediate_data_nonpsyc/pubmed18n1021.pkl', './intermediate_data_nonpsyc/pubmed18n1022.pkl', './intermediate_data_nonpsyc/pubmed18n1023.pkl', './intermediate_data_nonpsyc/pubmed18n1024.pkl']

# %%
combined_data = pd.concat([pd.read_pickle(f) for f in filenames], ignore_index=True)
combined_data # dim 77998 22
# Out:
#                                                 abstract  \
# 0      Antigens shared between Streptococcus pyogenes...
# 1      Association of group A streptococci with acute...
# 2      BACKGROUND\nThe excess risk of atherosclerosis...
# 3      The development of autoimmunity in certain ins...
# 4      The insulin resistance syndrome (IRS) is chara...
# 5      Chromatin assembly factor I (CAF-I) from human...
# 6      To examine the human antibody repertoire gener...
# 7      The role of small, dense LDL as a risk factor ...
# 8      In vivo, nucleosomes are formed rapidly on new...
# 9      Chromatin assembly factor 1 (CAF-1) assembles ...
# 10     In the yeast Saccharomyces cerevisiae, telomer...
# 11     The insulin resistance syndrome (IRS) is chara...
# 12     Factor analysis has previously identified four...
# 13     There is a growing body of evidence supporting...
# 14     To determine the relation between plasma trigl...
# ...

# %%
combined_data.to_csv("../data/nonpsyc_data.csv", index=False)

# %%
# clean up date type
combined_data['pubdate']= combined_data['pubdate'].astype(str)

# %%
# save data to pickle
combined_data.to_pickle("../data/nonpsyc_data.pkl")

# %%
# read data from pickle
nonpsyc = pd.read_pickle("../data/nonpsyc_data.pkl")
nonpsyc # dim 77998 22
# Out:
#                                                 abstract  \
# 0      Antigens shared between Streptococcus pyogenes...
# 1      Association of group A streptococci with acute...
# 2      BACKGROUND\nThe excess risk of atherosclerosis...
# 3      The development of autoimmunity in certain ins...
# 4      The insulin resistance syndrome (IRS) is chara...
# 5      Chromatin assembly factor I (CAF-I) from human...
# 6      To examine the human antibody repertoire gener...
# 7      The role of small, dense LDL as a risk factor ...
# 8      In vivo, nucleosomes are formed rapidly on new...
# 9      Chromatin assembly factor 1 (CAF-1) assembles ...
# 10     In the yeast Saccharomyces cerevisiae, telomer...
# 11     The insulin resistance syndrome (IRS) is chara...
# 12     Factor analysis has previously identified four...
# 13     There is a growing body of evidence supporting...
# 14     To determine the relation between plasma trigl...
# ...

# %%
nonpsyc['abstract'][0]
# Out:
# 'Antigens shared between Streptococcus pyogenes and heart tissue may play an important role in autoimmune cardiac injury associated with acute rheumatic fever. Antiheart/antistreptococcal antibodies found in the disease react with antigens of S. pyogenes, including M protein and a 60-kDa antigen distinct from M protein. Heart antigens recognized by these cross-reactive antistreptococcal antibodies include myosin and actin. To investigate the presence of a streptococcal actin, established protocols for the polymerization and isolation of eukaryotic actin were used to extract and concentrate actinlike proteins from M- streptococcal cells. The polymerized bacterial actin from the streptococcal extract was probed in immunoblots with an antiactin monoclonal antibody. Two proteins of about 60 kDa in the polymerized bacterial actin reacted with the antiactin antibody. Proteins in the polymerized bacterial actin extract of about 43 and 60 kDa behaved like eukaryotic actin by binding to myosi
# ...
